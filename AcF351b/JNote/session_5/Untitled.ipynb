# %%
try:
    import wrds
except ImportError:
    # !pip install wrds

# %%
conn = wrds.Connection()
# Out:
# Enter your WRDS username [Owner]:hchan1
# Enter your password:········
# WRDS recommends setting up a .pgpass file.
# You can find more info here:
# https://www.postgresql.org/docs/9.5/static/libpq-pgpass.html.
# Loading library list...
# Done

# %%
import random

libraries = conn.list_libraries()

libraries[:10]
# Out:
# ['wrds_lib_internal',
#  'ppubsamp_d4d_new',
#  'ktmine',
#  'ibescorp',
#  'contrib_char_returns_new',
#  'taq',
#  'secsamp_all_new',
#  'compd',
#  'compgd',
#  'preqsamp_all_new']

# %%
library = "crsp"

tables = conn.list_tables(library = library)

tables[:10]
# Out:
# ['ccm_lookup',
#  'ccm_qvards',
#  'ccmxpf_linktable',
#  'ccmxpf_lnkhist',
#  'ccmxpf_lnkrng',
#  'ccmxpf_lnkused',
#  'comphead',
#  'comphist',
#  'compmaster',
#  'cst_hist']

# %%
library = "crsp"

table = "dse"

conn.describe_table(library = library, table  = table).head()
# Out:
# Approximately 11479800 rows in crsp.dse.
#      name  nullable              type
# 0   event      True           VARCHAR
# 1    date      True              DATE
# 2  hsicmg      True  DOUBLE PRECISION
# 3  hsicig      True  DOUBLE PRECISION
# 4  comnam      True           VARCHAR

# %%
library = "crsp"
table = "dsf"
columns = ["cusip, permno, permco, date, prc, openprc, bid, bidlo, ask, askhi, vol, ret, retx"]
obs = 20

conn.get_table(library = library, table = table, columns = columns, obs = obs)
# Out:
#        cusip   permno   permco        date        prc    openprc        bid  \
# 0   33738R88  14804.0  54165.0  2015-11-23  18.000000  17.950001  17.969999
# 1   33738R88  14804.0  54165.0  2015-11-24  17.900000  17.809999  17.879999
# 2   33738R88  14804.0  54165.0  2015-11-25  18.000000  17.910000  17.990000
# 3   33738R88  14804.0  54165.0  2015-11-27  17.920000  18.000000  17.959999
# 4   33738R88  14804.0  54165.0  2015-11-30  18.130100  18.090000  18.129999
# 5   33738R88  14804.0  54165.0  2015-12-01  18.280001  18.190001  18.260000
# 6   33738R88  14804.0  54165.0  2015-12-02  18.139999  18.209999  18.129999
# 7   33738R88  14804.0  54165.0  2015-12-03  18.129999  18.160000  18.100000
# 8   33738R88  14804.0  54165.0  2015-12-04  18.350000  18.070000  18.340000
# 9   33738R88  14804.0  54165.0  2015-12-07  18.250000  18.180000  18.250000
